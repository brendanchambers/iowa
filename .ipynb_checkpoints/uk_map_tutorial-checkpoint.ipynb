# %%
import matplotlib.pyplot as plt
import matplotlib.cm
 
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.colors import Normalize

import pandas as pd
import numpy as np

# https://github.com/jamalmoir/notebook_playground/blob/master/uk_2015_houseprice.ipynb
# tutorial - http://www.datadependence.com/2016/06/creating-map-visualisations-in-python/

# %%
fig, ax = plt.subplots(figsize=(10,20))

m = Basemap(resolution='c', # c, l, i, h, f or None
            projection='merc',
            lat_0=54.5, lon_0=-4.36,
            llcrnrlon=-6., llcrnrlat= 49.5, urcrnrlon=2., urcrnrlat=55.2)

m.drawmapboundary(fill_color='#46bcec')
m.fillcontinents(color='#f2f2f2',lake_color='#46bcec')
m.drawcoastlines()

m.drawmapboundary(fill_color='#46bcec')
m.fillcontinents(color='#f2f2f2',lake_color='#46bcec')
m.drawcoastlines()

print 'reading shape file...'

m.readshapefile('data/uk_postcode_bounds/Areas', 'areas')

print 'constructing data frame...'

df_poly = pd.DataFrame({
        'shapes': [Polygon(np.array(shape), True) for shape in m.areas],
        'area': [area['name'] for area in m.areas_info]
    })
df_poly = df_poly.merge(new_areas, on='area', how='left')

df_poly = pd.DataFrame({
        'shapes': [Polygon(np.array(shape), True) for shape in m.areas],
        'area': [area['name'] for area in m.areas_info]
    })
df_poly = df_poly.merge(new_areas, on='area', how='left')
# Out:
# reading shape file...
# constructing data frame...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-efa6161bd148> in <module>()
#      24         'area': [area['name'] for area in m.areas_info]
#      25     })
# ---> 26 df_poly = df_poly.merge(new_areas, on='area', how='left')
#      27
#      28 df_poly = pd.DataFrame({
#
# NameError: name 'new_areas' is not defined
